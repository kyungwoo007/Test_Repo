# %% [markdown]
# <a href="https://colab.research.google.com/github/kyungwoo007/Test_Repo/blob/main/naver_kang_news.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
import pandas as pd
from PyPDF2 import PdfReader


# Step 1: PDF에서 텍스트 추출
def extract_text_from_pdf(pdf_file_path):
    reader = PdfReader(pdf_file_path)
    pdf_content = [page.extract_text() for page in reader.pages]
    return "\n".join(pdf_content)

# Step 2: "한양대 강경우 교수"가 언급된 뉴스 추출
def extract_articles_with_professor(text):
    # 제목, URL, 강경우 교수의 코멘트를 포함한 정규 표현식
    pattern = r"\d+\.\s(.+?)\n(https?://[^\s]+)\n.*?<b>강경우</b>.*?<b>한양대</b>.*?<b>교수</b>(.+?)\n"
    matches = re.findall(pattern, text, re.DOTALL)

    # 뉴스 정보를 리스트로 저장
    articles = []
    for match in matches:
        articles.append({
            "제목": match[0].strip(),
            "URL": match[1].strip(),
            "코멘트": match[2].strip(),
        })
    return articles

# Step 3: 데이터를 날짜별로 정렬 후 엑셀로 저장
def save_articles_to_excel(articles, output_file_path):
    df = pd.DataFrame(articles)

    # 날짜 열이 없으므로 추가하거나 파일 정렬 로직에 따라 수정 가능
    # 날짜 열이 없을 경우, 기본 순서를 역순으로 설정
    df = df.iloc[::-1]

    # 엑셀 저장
    df.to_excel(output_file_path, index=False, engine="openpyxl")
    print(f"엑셀 파일이 저장되었습니다: {output_file_path}")

# Main 함수
if __name__ == "__main__":
    # PDF 파일 경로와 저장할 엑셀 파일 경로
    pdf_file_path = "naver.pdf"  # 주어진 PDF 파일 경로
    output_file_path = "news-2.xlsx"  # 결과를 저장할 엑셀 파일 경로

    # PDF 텍스트 추출
    print("PDF 파일에서 텍스트를 추출 중입니다...")
    pdf_text = extract_text_from_pdf(pdf_file_path)

    # "한양대 강경우 교수"가 언급된 뉴스 추출
    print("강경우 교수가 언급된 뉴스 기사 추출 중입니다...")
    filtered_articles = extract_articles_with_professor(pdf_text)

    # 엑셀 파일 저장
import re
import pandas as pd
from PyPDF2 import PdfReader


# Step 1: PDF에서 텍스트 추출
def extract_text_from_pdf(pdf_file_path):
    reader = PdfReader(pdf_file_path)
    pdf_content = [page.extract_text() for page in reader.pages]
    return "\n".join(pdf_content)

# Step 2: "한양대 강경우 교수"가 언급된 뉴스 추출
def extract_articles_with_professor(text):
    # 제목, URL, 강경우 교수의 코멘트를 포함한 정규 표현식
    pattern = r"\d+\.\s(.+?)\n(https?://[^\s]+)\n.*?<b>강경우</b>.*?<b>한양대</b>.*?<b>교수</b>(.+?)\n"
    matches = re.findall(pattern, text, re.DOTALL)

    # 뉴스 정보를 리스트로 저장
    articles = []
    for match in matches:
        articles.append({
            "제목": match[0].strip(),
            "URL": match[1].strip(),
            "코멘트": match[2].strip(),
        })
    return articles

# Step 3: 데이터를 날짜별로 정렬 후 엑셀로 저장
def save_articles_to_excel(articles, output_file_path):
    df = pd.DataFrame(articles)

    # 날짜 열이 없으므로 추가하거나 파일 정렬 로직에 따라 수정 가능
    # 날짜 열이 없을 경우, 기본 순서를 역순으로 설정
    df = df.iloc[::-1]

    # 엑셀 저장
    df.to_excel(output_file_path, index=False, engine="openpyxl")
    print(f"엑셀 파일이 저장되었습니다: {output_file_path}")

# Main 함수
if __name__ == "__main__":
    # PDF 파일 경로와 저장할 엑셀 파일 경로
    pdf_file_path = "naver.pdf"  # 주어진 PDF 파일 경로
    output_file_path = "news-2.xlsx"  # 결과를 저장할 엑셀 파일 경로

    # PDF 텍스트 추출
    print("PDF 파일에서 텍스트를 추출 중입니다...")
    pdf_text = extract_text_from_pdf(pdf_file_path)

    # "한양대 강경우 교수"가 언급된 뉴스 추출
    print("강경우 교수가 언급된 뉴스 기사 추출 중입니다...")
    filtered_articles = extract_articles_with_professor(pdf_text)

    # 엑셀 파일 저장
    print("추출한 데이터를 엑셀 파일로 저장 중입니다...")
import re
import pandas as pd
from PyPDF2 import PdfReader


# Step 1: PDF에서 텍스트 추출
def extract_text_from_pdf(pdf_file_path):
    reader = PdfReader(pdf_file_path)
    pdf_content = [page.extract_text() for page in reader.pages]
    return "\n".join(pdf_content)

# Step 2: "한양대 강경우 교수"가 언급된 뉴스 추출
def extract_articles_with_professor(text):
    # 제목, URL, 강경우 교수의 코멘트를 포함한 정규 표현식
    pattern = r"\d+\.\s(.+?)\n(https?://[^\s]+)\n.*?<b>강경우</b>.*?<b>한양대</b>.*?<b>교수</b>(.+?)\n"
    matches = re.findall(pattern, text, re.DOTALL)

    # 뉴스 정보를 리스트로 저장
    articles = []
    for match in matches:
        articles.append({
            "제목": match[0].strip(),
            "URL": match[1].strip(),
            "코멘트": match[2].strip(),
        })
    return articles

# Step 3: 데이터를 날짜별로 정렬 후 엑셀로 저장
def save_articles_to_excel(articles, output_file_path):
    df = pd.DataFrame(articles)

    # 날짜 열이 없으므로 추가하거나 파일 정렬 로직에 따라 수정 가능
    # 날짜 열이 없을 경우, 기본 순서를 역순으로 설정
    df = df.iloc[::-1]

    # 엑셀 저장
    df.to_excel(output_file_path, index=False, engine="openpyxl")
    print(f"엑셀 파일이 저장되었습니다: {output_file_path}")

# Main 함수
if __name__ == "__main__":
    # PDF 파일 경로와 저장할 엑셀 파일 경로
    pdf_file_path = "naver.pdf"  # 주어진 PDF 파일 경로
    output_file_path = "news-2.xlsx"  # 결과를 저장할 엑셀 파일 경로

    # PDF 텍스트 추출
    print("PDF 파일에서 텍스트를 추출 중입니다...")
    pdf_text = extract_text_from_pdf(pdf_file_path)

    # "한양대 강경우 교수"가 언급된 뉴스 추출
    print("강경우 교수가 언급된 뉴스 기사 추출 중입니다...")
    filtered_articles = extract_articles_with_professor(pdf_text)

    # 엑셀 파일 저장
    print("추출한 데이터를 엑셀 파일로 저장 중입니다...")
    save_articles_to_excel(filtered_articles, output_file_path)
def extract_articles_with_professor(text):
    # 제목, URL, 강경우 교수의 코멘트를 포함한 정규 표현식
    pattern = r"\d+\.\s(.+?)\n(https?://[^\s]+)\n.*?<b>강경우</b>.*?<b>한양대</b>.*?<b>교수</b>(.+?)\n"
    matches = re.findall(pattern, text, re.DOTALL)

    # 뉴스 정보를 리스트로 저장
    articles = []
    for match in matches:
        articles.append({
            "제목": match[0].strip(),
            "URL": match[1].strip(),
            "코멘트": match[2].strip(),
        })
    return articles

# Step 3: 데이터를 날짜별로 정렬 후 엑셀로 저장
def save_articles_to_excel(articles, output_file_path):
    df = pd.DataFrame(articles)

    # 날짜 열이 없으므로 추가하거나 파일 정렬 로직에 따라 수정 가능
    # 날짜 열이 없을 경우, 기본 순서를 역순으로 설정
    df = df.iloc[::-1]

    # 엑셀 저장
    df.to_excel(output_file_path, index=False, engine="openpyxl")
    print(f"엑셀 파일이 저장되었습니다: {output_file_path}")

# Main 함수
if __name__ == "__main__":
    # PDF 파일 경로와 저장할 엑셀 파일 경로
    pdf_file_path = "naver.pdf"  # 주어진 PDF 파일 경로
    output_file_path = "news-2.xlsx"  # 결과를 저장할 엑셀 파일 경로

    # PDF 텍스트 추출
    print("PDF 파일에서 텍스트를 추출 중입니다...")
    pdf_text = extract_text_from_pdf(pdf_file_path)

    # "한양대 강경우 교수"가 언급된 뉴스 추출
    print("강경우 교수가 언급된 뉴스 기사 추출 중입니다...")
    filtered_articles = extract_articles_with_professor(pdf_text)

    # 엑셀 파일 저장
    print("추출한 데이터를 엑셀 파일로 저장 중입니다...")
    save_articles_to_excel(filtered_articles, output_file_path)
# Step 2: "한양대 강경우 교수"가 언급된 뉴스 추출
def extract_articles_with_professor(text):
    # 제목, URL, 강경우 교수의 코멘트를 포함한 정규 표현식
    pattern = r"\d+\.\s(.+?)\n(https?://[^\s]+)\n.*?<b>강경우</b>.*?<b>한양대</b>.*?<b>교수</b>(.+?)\n"
    matches = re.findall(pattern, text, re.DOTALL)

    # 뉴스 정보를 리스트로 저장
    articles = []
    for match in matches:
        articles.append({
            "제목": match[0].strip(),
            "URL": match[1].strip(),
            "코멘트": match[2].strip(),
        })
    return articles

# Step 3: 데이터를 날짜별로 정렬 후 엑셀로 저장
def save_articles_to_excel(articles, output_file_path):
    df = pd.DataFrame(articles)

    # 날짜 열이 없으므로 추가하거나 파일 정렬 로직에 따라 수정 가능
    # 날짜 열이 없을 경우, 기본 순서를 역순으로 설정
    df = df.iloc[::-1]

    # 엑셀 저장
    df.to_excel(output_file_path, index=False, engine="openpyxl")
    print(f"엑셀 파일이 저장되었습니다: {output_file_path}")

# Main 함수
if __name__ == "__main__":
    # PDF 파일 경로와 저장할 엑셀 파일 경로
    pdf_file_path = "naver.pdf"  # 주어진 PDF 파일 경로
    output_file_path = "news-2.xlsx"  # 결과를 저장할 엑셀 파일 경로

    # PDF 텍스트 추출
    print("PDF 파일에서 텍스트를 추출 중입니다...")
    pdf_text = extract_text_from_pdf(pdf_file_path)

    # "한양대 강경우 교수"가 언급된 뉴스 추출
    print("강경우 교수가 언급된 뉴스 기사 추출 중입니다...")
    filtered_articles = extract_articles_with_professor(pdf_text)


# Main 함수
if __name__ == "__main__":
    # PDF 파일 경로와 저장할 엑셀 파일 경로
    pdf_file_path = "naver.pdf"  # 주어진 PDF 파일 경로
    output_file_path = "news-2.xlsx"  # 결과를 저장할 엑셀 파일 경로

    # PDF 텍스트 추출
    print("PDF 파일에서 텍스트를 추출 중입니다...")
    pdf_text = extract_text_from_pdf(pdf_file_path)

    # "한양대 강경우 교수"가 언급된 뉴스 추출
    print("강경우 교수가 언급된 뉴스 기사 추출 중입니다...")
    filtered_articles = extract_articles_with_professor(pdf_text)

    # 엑셀 파일 저장
    print("추출한 데이터를 엑셀 파일로 저장 중입니다...")
    save_articles_to_excel(filtered_articles, output_file_path)
# Step 2: "한양대 강경우 교수"가 언급된 뉴스 추출
def extract_articles_with_professor(text):
    # 제목, URL, 강경우 교수의 코멘트를 포함한 정규 표현식
    pattern = r"\d+\.\s(.+?)\n(https?://[^\s]+)\n.*?<b>강경우</b>.*?<b>한양대</b>.*?<b>교수</b>(.+?)\n"
    matches = re.findall(pattern, text, re.DOTALL)

    # 뉴스 정보를 리스트로 저장
    articles = []
    for match in matches:
        articles.append({
            "제목": match[0].strip(),
            "URL": match[1].strip(),
            "코멘트": match[2].strip(),
        })
    return articles

# Step 3: 데이터를 날짜별로 정렬 후 엑셀로 저장
def save_articles_to_excel(articles, output_file_path):
    df = pd.DataFrame(articles)

    # 날짜 열이 없으므로 추가하거나 파일 정렬 로직에 따라 수정 가능
    # 날짜 열이 없을 경우, 기본 순서를 역순으로 설정
    df = df.iloc[::-1]

    # 엑셀 저장
    df.to_excel(output_file_path, index=False, engine="openpyxl")
    print(f"엑셀 파일이 저장되었습니다: {output_file_path}")

# Main 함수
if __name__ == "__main__":
    # PDF 파일 경로와 저장할 엑셀 파일 경로
    pdf_file_path = "naver.pdf"  # 주어진 PDF 파일 경로
    output_file_path = "news-2.xlsx"  # 결과를 저장할 엑셀 파일 경로

    # PDF 텍스트 추출
    print("PDF 파일에서 텍스트를 추출 중입니다...")
    pdf_text = extract_text_from_pdf(pdf_file_path)

    # "한양대 강경우 교수"가 언급된 뉴스 추출
    print("강경우 교수가 언급된 뉴스 기사 추출 중입니다...")
    filtered_articles = extract_articles_with_professor(pdf_text)

    # 엑셀 파일 저장
    print("추출한 데이터를 엑셀 파일로 저장 중입니다...")
    save_articles_to_excel(filtered_articles, output_file_path)
# Out:
# PDF 파일에서 텍스트를 추출 중입니다...
# 강경우 교수가 언급된 뉴스 기사 추출 중입니다...
# PDF 파일에서 텍스트를 추출 중입니다...
# 강경우 교수가 언급된 뉴스 기사 추출 중입니다...
# 추출한 데이터를 엑셀 파일로 저장 중입니다...
# PDF 파일에서 텍스트를 추출 중입니다...
# 강경우 교수가 언급된 뉴스 기사 추출 중입니다...
# 추출한 데이터를 엑셀 파일로 저장 중입니다...
# 엑셀 파일이 저장되었습니다: news-2.xlsx
# PDF 파일에서 텍스트를 추출 중입니다...
# 강경우 교수가 언급된 뉴스 기사 추출 중입니다...
# 추출한 데이터를 엑셀 파일로 저장 중입니다...
# 엑셀 파일이 저장되었습니다: news-2.xlsx
# PDF 파일에서 텍스트를 추출 중입니다...
# 강경우 교수가 언급된 뉴스 기사 추출 중입니다...
# PDF 파일에서 텍스트를 추출 중입니다...
# 강경우 교수가 언급된 뉴스 기사 추출 중입니다...
# 추출한 데이터를 엑셀 파일로 저장 중입니다...
# 엑셀 파일이 저장되었습니다: news-2.xlsx
# PDF 파일에서 텍스트를 추출 중입니다...
# 강경우 교수가 언급된 뉴스 기사 추출 중입니다...
# 추출한 데이터를 엑셀 파일로 저장 중입니다...
# 엑셀 파일이 저장되었습니다: news-2.xlsx
